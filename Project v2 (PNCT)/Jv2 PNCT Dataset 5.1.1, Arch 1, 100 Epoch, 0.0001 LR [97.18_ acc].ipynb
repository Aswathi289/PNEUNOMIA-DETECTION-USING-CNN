# %% [markdown]
# # Importing the necessary libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from keras.optimizers import Adam
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # 1. Loading the dataset

# %%
# Define the labels
labels = ['PNEUMONIA', 'NORMAL', 'TUBERCULOSIS', 'COVID19']

# Set the image size
img_size = 150

# Function to load the training, test, and validation data
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        i = 1
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
                if(i%200 == 0):
                  print(i,class_num)
                i+=1
            except Exception as e:
                print(e)
    print("Data loaded")
    print()
    return np.array(data, dtype=object)

# %%
# Load the data

train = get_training_data('/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/train')
test = get_training_data('/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test')
val = get_training_data('/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/val')
# Out:
# 200 0
# 400 0
# 600 0
# 800 0
# 1000 0
# 1200 0
# 1400 0
# 1600 0
# 1800 0
# 2000 0
# 2200 0
# 2400 0
# 2600 0
# 2800 0
# 3000 0
# 3200 0
# 3400 0
# 200 1
# 400 1
# 600 1
# 800 1
# 1000 1
# 1200 1
# 1400 1
# 1600 1
# 1800 1
# 2000 1
# 2200 1
# 2400 1
# 2600 1
# 2800 1
# 200 2
# 400 2
# 600 2
# 800 2
# 200 3
# 400 3
# 600 3
# 800 3
# 1000 3
# 1200 3
# 1400 3
# 1600 3
# 1800 3
# 2000 3
# 2200 3
# 2400 3
# 2600 3
# 2800 3
# Data loaded
#
# 200 0
# 400 0
# 200 1
# 200 3
# Data loaded
#
# 200 0
# 400 0
# 200 1
# 200 3
# Data loaded

# %%
# Load the data

#train = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/train')
#test = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test')
#val = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/val')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-d8b3b760f06e> in <cell line: 3>()
#       1 # Load the data
#       2
# ----> 3 train = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/train')
#       4 test = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test')
#       5 val = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/val')
#
# <ipython-input-8-e4c08481bb73> in get_training_data(data_dir)
#      12         class_num = labels.index(label)
#      13         i = 1
# ---> 14         for img in os.listdir(path):
#      15             try:
#      16                 img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/train/PNEUMONIA'

# %% [markdown]
# # 2. Data Exploration

# %%
print(train[300])
train.shape
# Out:
# [array([[77, 91, 96, ..., 37, 33, 42],
#         [52, 61, 81, ..., 38, 33, 47],
#         [57, 59, 59, ..., 33, 29, 44],
#         ...,
#         [19, 19, 17, ..., 28, 28, 28],
#         [19, 19, 15, ..., 27, 28, 28],
#         [19, 19, 15, ..., 27, 28, 28]], dtype=uint8) 0]
# (9918, 2)

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    elif(i[1] == 1):
        l.append("Normal")
    elif(i[1] == 2):
        l.append("Tuberculosis")
    elif(i[1] == 3):
        l.append("Covid19")
print(l)
# Out:
# ['Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumon ...

# %%
sns.set_style('darkgrid')
sns.countplot(x=l)
# Out:
# <Axes: ylabel='count'>

# %%
# Previewing an image from each class

plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[3600][0], cmap='gray')
plt.title(labels[train[3600][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[6600][0], cmap='gray')
plt.title(labels[train[6500][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'COVID19')

# %%
# Split the data into features and labels

x_train = []
y_train = []
x_val = []
y_val = []
x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)
for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Accessing the no. of elements of each class in train, test, and val respectively

from collections import Counter

def get_element_frequency(arr):
    frequency_counter = Counter(arr)
    return frequency_counter

for i in (y_train,y_test,y_val):
    frequency = get_element_frequency(i)
    for element, count in frequency.items():
        print(f"The element {element} appears {count} times.")
    print()
# Out:
# The element 0 appears 3425 times.
# The element 1 appears 2800 times.
# The element 2 appears 813 times.
# The element 3 appears 2880 times.
#
# The element 0 appears 427 times.
# The element 1 appears 350 times.
# The element 2 appears 100 times.
# The element 3 appears 367 times.
#
# The element 0 appears 427 times.
# The element 1 appears 350 times.
# The element 2 appears 99 times.
# The element 3 appears 366 times.

# %%
num_test_samples = len(x_train)
print("Number of x_train samples:", num_test_samples)

num_test_samples = len(x_test)
print("Number of x_test samples:", num_test_samples)

num_test_samples = len(x_val)
print("Number of x_val samples:", num_test_samples)
# Out:
# Number of x_train samples: 9918
# Number of x_test samples: 1244
# Number of x_val samples: 1242

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# **Normalization:** We perform a grayscale normalization to reduce the effect of illumination's differences.Moreover the CNN converges faster on [0..1] data than on [0..255].

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# Resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
# Convert class vectors to binary class matrices (one-hot encoding)

y_train = to_categorical(y_train, num_classes=4)
y_val = to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# %% [markdown]
# # 4. Model Training

# %%
# from tensorflow.keras.models import load_model

# model = load_model("/content/Model of Jv2 [95.52% acc] Dataset 5.1, 100 epoch, 16 batch size.h5")

# %%
# Building the model

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))  # Adjust the number of classes here

optimizer = Adam(learning_rate = 0.0001)
model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_4 (Conv2D)           (None, 148, 148, 32)      320
#
#  batch_normalization_4 (Batc  (None, 148, 148, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 74, 74, 32)       0
#  2D)
#
#  conv2d_5 (Conv2D)           (None, 72, 72, 64)        18496
#
#  batch_normalization_5 (Batc  (None, 72, 72, 64)       256
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 34, 34, 128)       73856
#
#  batch_normalization_6 (Batc  (None, 34, 34, 128)      512
#  hNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 15, 15, 256)       295168
#
#  batch_normalization_7 (Batc  (None, 15, 15, 256)      1024
#  hNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 12544)             0
#
#  dense_4 (Dense)             (None, 512)               6423040
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 6,977,540
# Trainable params: 6,976,580
# Non-trainable params: 960
# _________________________________________________________________

# %%
len(model.layers)
# Out:
# 20

# %%
# Model Architecture Visualization

from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
#learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)

# %%
# Training the model

history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 310/310 [==============================] - 11s 33ms/step - loss: 1.0008 - accuracy: 0.6738 - val_loss: 1.0605 - val_accuracy: 0.5386
# Epoch 2/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.4537 - accuracy: 0.8336 - val_loss: 0.3508 - val_accuracy: 0.8583
# Epoch 3/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.2910 - accuracy: 0.9018 - val_loss: 2.2438 - val_accuracy: 0.5982
# Epoch 4/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.1968 - accuracy: 0.9339 - val_loss: 0.1337 - val_accuracy: 0.9533
# Epoch 5/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.1302 - accuracy: 0.9567 - val_loss: 0.6592 - val_accuracy: 0.8567
# Epoch 6/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.1103 - accuracy: 0.9650 - val_loss: 0.1803 - val_accuracy: 0.9396
# Epoch 7/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.1047 - accuracy: 0.9689 - val_loss: 0.3713 - val_accuracy: 0.8631
# Epoch 8/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0850 - accuracy: 0.9733 - val_loss: 0.5332 - val_accuracy: 0.9050
# Epoch 9/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0690 - accuracy: 0.9799 - val_loss: 1.0721 - val_accuracy: 0.8430
# Epoch 10/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0488 - accuracy: 0.9859 - val_loss: 0.3834 - val_accuracy: 0.9283
# Epoch 11/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0521 - accuracy: 0.9854 - val_loss: 0.0542 - val_accuracy: 0.9815
# Epoch 12/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0474 - accuracy: 0.9858 - val_loss: 0.9589 - val_accuracy: 0.7778
# Epoch 13/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0429 - accuracy: 0.9878 - val_loss: 0.1099 - val_accuracy: 0.9718
# Epoch 14/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0473 - accuracy: 0.9859 - val_loss: 0.9604 - val_accuracy: 0.7617
# Epoch 15/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0312 - accuracy: 0.9907 - val_loss: 0.8459 - val_accuracy: 0.8961
# Epoch 16/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0329 - accuracy: 0.9907 - val_loss: 0.8101 - val_accuracy: 0.8881
# Epoch 17/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0606 - accuracy: 0.9841 - val_loss: 1.8270 - val_accuracy: 0.6667
# Epoch 18/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0327 - accuracy: 0.9907 - val_loss: 3.9423 - val_accuracy: 0.6651
# Epoch 19/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0198 - accuracy: 0.9934 - val_loss: 0.7833 - val_accuracy: 0.8108
# Epoch 20/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0409 - accuracy: 0.9883 - val_loss: 0.9683 - val_accuracy: 0.8671
# Epoch 21/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0291 - accuracy: 0.9924 - val_loss: 0.1917 - val_accuracy: 0.9340
# Epoch 22/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0162 - accuracy: 0.9946 - val_loss: 0.3229 - val_accuracy: 0.9420
# Epoch 23/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0279 - accuracy: 0.9925 - val_loss: 32.9621 - val_accuracy: 0.3229
# Epoch 24/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0289 - accuracy: 0.9932 - val_loss: 0.6087 - val_accuracy: 0.8454
# Epoch 25/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0264 - accuracy: 0.9935 - val_loss: 0.7702 - val_accuracy: 0.8519
# Epoch 26/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0278 - accuracy: 0.9924 - val_loss: 1.0662 - val_accuracy: 0.8543
# Epoch 27/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0271 - accuracy: 0.9930 - val_loss: 0.0795 - val_accuracy: 0.9702
# Epoch 28/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0148 - accuracy: 0.9961 - val_loss: 0.0572 - val_accuracy: 0.9823
# Epoch 29/100
# 310/310 [==============================] - 10s 33ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.2890 - val_accuracy: 0.9509
# Epoch 30/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0233 - accuracy: 0.9943 - val_loss: 1.2232 - val_accuracy: 0.7568
# Epoch 31/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.3789 - val_accuracy: 0.9147
# Epoch 32/100
# 310/310 [==============================] - 10s 33ms/step - loss: 0.0112 - accuracy: 0.9970 - val_loss: 12.5187 - val_accuracy: 0.5515
# Epoch 33/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0237 - accuracy: 0.9951 - val_loss: 0.0860 - val_accuracy: 0.9855
# Epoch 34/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0132 - accuracy: 0.9957 - val_loss: 2.8971 - val_accuracy: 0.7689
# Epoch 35/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0208 - accuracy: 0.9954 - val_loss: 0.6660 - val_accuracy: 0.9122
# Epoch 36/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0055 - accuracy: 0.9983 - val_loss: 0.2812 - val_accuracy: 0.9227
# Epoch 37/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0141 - accuracy: 0.9965 - val_loss: 0.0424 - val_accuracy: 0.9871
# Epoch 38/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0169 - accuracy: 0.9962 - val_loss: 2.3226 - val_accuracy: 0.7093
# Epoch 39/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0150 - accuracy: 0.9963 - val_loss: 1.6220 - val_accuracy: 0.8301
# Epoch 40/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0073 - accuracy: 0.9979 - val_loss: 0.0381 - val_accuracy: 0.9887
# Epoch 41/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0086 - accuracy: 0.9981 - val_loss: 0.1356 - val_accuracy: 0.9742
# Epoch 42/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0195 - accuracy: 0.9957 - val_loss: 2.1713 - val_accuracy: 0.8035
# Epoch 43/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0110 - accuracy: 0.9969 - val_loss: 0.5913 - val_accuracy: 0.9195
# Epoch 44/100
# 310/310 [==============================] - 10s 33ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 45.2558 - val_accuracy: 0.3519
# Epoch 45/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0089 - accuracy: 0.9975 - val_loss: 1.1094 - val_accuracy: 0.8607
# Epoch 46/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0108 - accuracy: 0.9972 - val_loss: 1.1598 - val_accuracy: 0.8551
# Epoch 47/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0218 - accuracy: 0.9950 - val_loss: 27.1536 - val_accuracy: 0.4283
# Epoch 48/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0129 - accuracy: 0.9973 - val_loss: 0.5434 - val_accuracy: 0.9179
# Epoch 49/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0175 - accuracy: 0.9961 - val_loss: 0.0211 - val_accuracy: 0.9919
# Epoch 50/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0069 - accuracy: 0.9980 - val_loss: 1.0045 - val_accuracy: 0.8551
# Epoch 51/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0146 - val_accuracy: 0.9960
# Epoch 52/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0023 - accuracy: 0.9990 - val_loss: 0.0484 - val_accuracy: 0.9887
# Epoch 53/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0182 - accuracy: 0.9967 - val_loss: 4.5813 - val_accuracy: 0.7464
# Epoch 54/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0232 - accuracy: 0.9950 - val_loss: 6.2619 - val_accuracy: 0.6723
# Epoch 55/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0067 - accuracy: 0.9981 - val_loss: 0.0176 - val_accuracy: 0.9936
# Epoch 56/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0115 - accuracy: 0.9967 - val_loss: 0.4197 - val_accuracy: 0.9332
# Epoch 57/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0039 - accuracy: 0.9992 - val_loss: 0.2314 - val_accuracy: 0.9436
# Epoch 58/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0034 - accuracy: 0.9990 - val_loss: 0.0488 - val_accuracy: 0.9831
# Epoch 59/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0068 - accuracy: 0.9983 - val_loss: 24.5065 - val_accuracy: 0.4493
# Epoch 60/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0123 - accuracy: 0.9980 - val_loss: 0.1340 - val_accuracy: 0.9686
# Epoch 61/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0095 - accuracy: 0.9981 - val_loss: 1.1662 - val_accuracy: 0.8068
# Epoch 62/100
# 310/310 [==============================] - 10s 33ms/step - loss: 0.0159 - accuracy: 0.9961 - val_loss: 0.6748 - val_accuracy: 0.9195
# Epoch 63/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0081 - accuracy: 0.9986 - val_loss: 19.3169 - val_accuracy: 0.5636
# Epoch 64/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0038 - accuracy: 0.9986 - val_loss: 0.3030 - val_accuracy: 0.9372
# Epoch 65/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0056 - accuracy: 0.9984 - val_loss: 0.1200 - val_accuracy: 0.9597
# Epoch 66/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0088 - accuracy: 0.9976 - val_loss: 8.0240 - val_accuracy: 0.7351
# Epoch 67/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 7.7341 - val_accuracy: 0.7214
# Epoch 68/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0268 - accuracy: 0.9959 - val_loss: 0.2723 - val_accuracy: 0.9380
# Epoch 69/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0156 - accuracy: 0.9968 - val_loss: 0.2782 - val_accuracy: 0.9509
# Epoch 70/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0055 - accuracy: 0.9988 - val_loss: 14.5117 - val_accuracy: 0.5378
# Epoch 71/100
# 310/310 [==============================] - 10s 34ms/step - loss: 0.0050 - accuracy: 0.9982 - val_loss: 0.0621 - val_accuracy: 0.9879
# Epoch 72/100
# 310/310 [==============================] - 11s 36ms/step - loss: 0.0022 - accuracy: 0.9994 - val_loss: 1.9752 - val_accuracy: 0.8172
# Epoch 73/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0146 - accuracy: 0.9968 - val_loss: 1.5008 - val_accuracy: 0.8374
# Epoch 74/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0063 - accuracy: 0.9989 - val_loss: 21.5675 - val_accuracy: 0.4984
# Epoch 75/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0092 - accuracy: 0.9981 - val_loss: 0.1554 - val_accuracy: 0.9750
# Epoch 76/100
# 310/310 [==============================] - 10s 33ms/step - loss: 0.0094 - accuracy: 0.9971 - val_loss: 0.0617 - val_accuracy: 0.9871
# Epoch 77/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0053 - accuracy: 0.9991 - val_loss: 0.4280 - val_accuracy: 0.9420
# Epoch 78/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.4149 - val_accuracy: 0.9155
# Epoch 79/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0022 - accuracy: 0.9996 - val_loss: 0.2740 - val_accuracy: 0.9638
# Epoch 80/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0085 - accuracy: 0.9972 - val_loss: 0.0982 - val_accuracy: 0.9726
# Epoch 81/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0104 - accuracy: 0.9979 - val_loss: 0.5628 - val_accuracy: 0.9050
# Epoch 82/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0112 - accuracy: 0.9973 - val_loss: 1.1548 - val_accuracy: 0.8357
# Epoch 83/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0018 - accuracy: 0.9996 - val_loss: 0.2486 - val_accuracy: 0.9622
# Epoch 84/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0048 - accuracy: 0.9990 - val_loss: 2.0326 - val_accuracy: 0.8969
# Epoch 85/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0040 - accuracy: 0.9991 - val_loss: 1.6244 - val_accuracy: 0.8671
# Epoch 86/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0070 - accuracy: 0.9983 - val_loss: 2.9038 - val_accuracy: 0.8092
# Epoch 87/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0057 - accuracy: 0.9996 - val_loss: 4.6286 - val_accuracy: 0.6852
# Epoch 88/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 3.1360 - val_accuracy: 0.8583
# Epoch 89/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0187 - accuracy: 0.9968 - val_loss: 0.2294 - val_accuracy: 0.9614
# Epoch 90/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0196 - val_accuracy: 0.9936
# Epoch 91/100
# 310/310 [==============================] - 10s 33ms/step - loss: 7.7696e-04 - accuracy: 0.9998 - val_loss: 0.0143 - val_accuracy: 0.9960
# Epoch 92/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0056 - accuracy: 0.9992 - val_loss: 2.9661 - val_accuracy: 0.7335
# Epoch 93/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0058 - accuracy: 0.9982 - val_loss: 0.2670 - val_accuracy: 0.9646
# Epoch 94/100
# 310/310 [==============================] - 10s 33ms/step - loss: 0.0023 - accuracy: 0.9992 - val_loss: 1.4213 - val_accuracy: 0.8390
# Epoch 95/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0023 - accuracy: 0.9991 - val_loss: 5.5728 - val_accuracy: 0.7110
# Epoch 96/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0147 - accuracy: 0.9964 - val_loss: 0.0781 - val_accuracy: 0.9903
# Epoch 97/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0044 - accuracy: 0.9987 - val_loss: 7.6582 - val_accuracy: 0.6602
# Epoch 98/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0033 - accuracy: 0.9989 - val_loss: 0.0730 - val_accuracy: 0.9895
# Epoch 99/100
# 310/310 [==============================] - 10s 32ms/step - loss: 0.0039 - accuracy: 0.9985 - val_loss: 49.0691 - val_accuracy: 0.3325
# Epoch 100/100
# 310/310 [==============================] - 10s 31ms/step - loss: 0.0096 - accuracy: 0.9976 - val_loss: 0.1533 - val_accuracy: 0.9718

# %%
print("Loss of the model is - ", model.evaluate(x_test, y_test)[0])
print("Accuracy of the model is - ", model.evaluate(x_test, y_test)[1] * 100, "%")
# Out:
# 39/39 [==============================] - 0s 11ms/step - loss: 0.2076 - accuracy: 0.9719
# Loss of the model is -  0.20760972797870636
# 39/39 [==============================] - 0s 10ms/step - loss: 0.2076 - accuracy: 0.9719
# Accuracy of the model is -  97.18649387359619 %

# %%
#model.save("Model of Jv2 [97.18% acc] Dataset 5.1.1, Arch 1, 100 epoch, 16 batch size.h5")

# %% [markdown]
# # 5. Post-Training Analysis:

# %%
plt.figure(figsize=[10,6])
plt.plot(history.history["accuracy"], label = "Train acc")
plt.plot(history.history["val_accuracy"], label = "Validation acc")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label = "Train loss")
plt.plot(history.history['val_loss'], label = "Validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # 6. Precision, Recall, F1-score, Support

# %%
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)  # Convert predictions to class labels
true_labels = np.argmax(y_test, axis=1)  # Convert true labels to class labels
# Out:
# 39/39 [==============================] - 0s 9ms/step

# %%
print(classification_report(true_labels, predicted_labels, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    PNEUMONIA       1.00      0.98      0.99       427
#       NORMAL       0.99      0.95      0.97       350
# TUBERCULOSIS       1.00      0.91      0.95       100
#      COVID19       0.92      1.00      0.96       367
#
#     accuracy                           0.97      1244
#    macro avg       0.98      0.96      0.97      1244
# weighted avg       0.97      0.97      0.97      1244

# %% [markdown]
# # 7. Confusion Matrix

# %%
cm = confusion_matrix(true_labels, predicted_labels)
cm
# Out:
# array([[420,   1,   0,   6],
#        [  0, 332,   0,  18],
#        [  0,   1,  91,   8],
#        [  0,   1,   0, 366]])

# %%
cm = pd.DataFrame(cm, index=labels, columns=labels)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(cm, cmap="Blues", linecolor='black', linewidth=1, annot=True, fmt='', xticklabels=labels, yticklabels=labels)
plt.show()

# %% [markdown]
# # 8. ROC Curve

# %%
y_pred = model.predict(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

num_classes = 4

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure(figsize=(12,12))

# Plot ROC curves for each class
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for class %s' % (roc_auc[i], labels[i]))

# Plot micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], label='Micro-average ROC curve (area = %0.2f)' % roc_auc["micro"], linestyle=':', linewidth=4)

# Add labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 39/39 [==============================] - 0s 10ms/step

# %% [markdown]
# # 9. Visualizing the predicted images

# %%
correct = np.nonzero(predicted_labels == true_labels)[0]
incorrect = np.nonzero(predicted_labels != true_labels)[0]

# %%
correct
# Out:
# array([   0,    1,    2, ..., 1241, 1242, 1243])

# %%
correct.size
# Out:
# 1238

# %%
incorrect
# Out:
# array([ 79, 299, 470, 514, 868, 914])

# %%
incorrect.size
# Out:
# 6

# %%
# Visualize correctly classified images

fig, axes = plt.subplots(2, 3, figsize=(10, 8))
fig.suptitle('Correctly Classified Images', fontsize=16)
for i, idx in enumerate(correct[:6]):
    row = i // 3
    col = i % 3
    axes[row, col].imshow(x_test[idx].reshape(img_size, img_size), cmap="gray", interpolation='none')
    axes[row, col].set_title("Predicted Class: {}\nTrue Class: {}".format(labels[predicted_labels[idx]], labels[true_labels[idx]]))
    axes[row, col].axis('off')
plt.tight_layout()
plt.show()

# %%
# Visualize incorrectly classified images

fig, axes = plt.subplots(2, 3, figsize=(10, 8))
fig.suptitle('Incorrectly Classified Images', fontsize=16)
for i, idx in enumerate(incorrect[:6]):
    row = i // 3
    col = i % 3
    axes[row, col].imshow(x_test[idx].reshape(img_size, img_size), cmap="gray", interpolation='none')
    axes[row, col].set_title("Predicted Class: {}\nTrue Class: {}".format(labels[predicted_labels[idx]], labels[true_labels[idx]]))
    axes[row, col].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10. Random Predictions

# %%
image = '/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test/TUBERCULOSIS/1.3.6.1.4.1.25403.163683357445804.11044.20131119114302.50.png'
def preprocess_image(image_path):
    img_arr = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_arr = cv2.resize(img_arr, (img_size, img_size))
    preprocessed_img = np.array(resized_arr) / 255.0
    preprocessed_img = preprocessed_img.reshape(-1, img_size, img_size, 1)
    return preprocessed_img

# Assuming 'image' is the variable containing the path to the image you want to predict
preprocessed_img = preprocess_image(image)
prediction = model.predict(preprocessed_img)
predicted_class = labels[np.argmax(prediction)]
print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 18ms/step
# Predicted class: TUBERCULOSIS
