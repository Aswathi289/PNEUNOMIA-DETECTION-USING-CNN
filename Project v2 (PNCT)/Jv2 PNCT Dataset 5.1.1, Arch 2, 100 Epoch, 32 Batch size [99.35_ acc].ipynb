# %% [markdown]
# # Importing the necessary libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # 1. Loading the dataset

# %%
# Define the labels
labels = ['PNEUMONIA', 'NORMAL', 'TUBERCULOSIS', 'COVID19']

# Set the image size
img_size = 150

# Function to load the training, test, and validation data
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        i = 1
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
                if(i%200 == 0):
                  print(i,class_num)
                i+=1
            except Exception as e:
                print(e)
    print("Data loaded")
    print()
    return np.array(data, dtype=object)

# %%
# Load the data

train = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/train')
test = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test')
val = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/val')
# Out:
# 200 0
# 400 0
# 600 0
# 800 0
# 1000 0
# 1200 0
# 1400 0
# 1600 0
# 1800 0
# 2000 0
# 2200 0
# 2400 0
# 2600 0
# 2800 0
# 3000 0
# 3200 0
# 3400 0
# 200 1
# 400 1
# 600 1
# 800 1
# 1000 1
# 1200 1
# 1400 1
# 1600 1
# 1800 1
# 2000 1
# 2200 1
# 2400 1
# 2600 1
# 2800 1
# 200 2
# 400 2
# 600 2
# 800 2
# 200 3
# 400 3
# 600 3
# 800 3
# 1000 3
# 1200 3
# 1400 3
# 1600 3
# 1800 3
# 2000 3
# 2200 3
# 2400 3
# 2600 3
# 2800 3
# Data loaded
#
# 200 0
# 400 0
# 200 1
# 200 3
# Data loaded
#
# 200 0
# 400 0
# 200 1
# 200 3
# Data loaded

# %% [markdown]
# # 2. Data Exploration

# %%
print(train[300])
train.shape
# Out:
# [array([[77, 91, 96, ..., 37, 33, 42],
#         [52, 61, 81, ..., 38, 33, 47],
#         [57, 59, 59, ..., 33, 29, 44],
#         ...,
#         [19, 19, 17, ..., 28, 28, 28],
#         [19, 19, 15, ..., 27, 28, 28],
#         [19, 19, 15, ..., 27, 28, 28]], dtype=uint8) 0]
# (9918, 2)

# %%
l = []
for i in train:
    if(i[1] == 0):
        l.append("Pneumonia")
    elif(i[1] == 1):
        l.append("Normal")
    elif(i[1] == 2):
        l.append("Tuberculosis")
    elif(i[1] == 3):
        l.append("Covid19")
print(l)
# Out:
# ['Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumon ...

# %%
sns.set_style('darkgrid')
sns.countplot(x=l)
# Out:
# <Axes: ylabel='count'>

# %%
# Previewing an image from each class

plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[3600][0], cmap='gray')
plt.title(labels[train[3600][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[6600][0], cmap='gray')
plt.title(labels[train[6500][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# Text(0.5, 1.0, 'COVID19')

# %%
# Split the data into features and labels

x_train = []
y_train = []
x_val = []
y_val = []
x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)
for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Accessing the no. of elements of each class in train, test, and val respectively

from collections import Counter

def get_element_frequency(arr):
    frequency_counter = Counter(arr)
    return frequency_counter

for i in (y_train,y_test,y_val):
    frequency = get_element_frequency(i)
    for element, count in frequency.items():
        print(f"The element {element} appears {count} times.")
    print()
# Out:
# The element 0 appears 3425 times.
# The element 1 appears 2800 times.
# The element 2 appears 813 times.
# The element 3 appears 2880 times.
#
# The element 0 appears 427 times.
# The element 1 appears 350 times.
# The element 2 appears 100 times.
# The element 3 appears 367 times.
#
# The element 0 appears 427 times.
# The element 1 appears 350 times.
# The element 2 appears 99 times.
# The element 3 appears 366 times.

# %%
num_test_samples = len(x_train)
print("Number of x_train samples:", num_test_samples)

num_test_samples = len(x_test)
print("Number of x_test samples:", num_test_samples)

num_test_samples = len(x_val)
print("Number of x_val samples:", num_test_samples)
# Out:
# Number of x_train samples: 9918
# Number of x_test samples: 1244
# Number of x_val samples: 1242

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# **Normalization:** We perform a grayscale normalization to reduce the effect of illumination's differences.Moreover the CNN converges faster on [0..1] data than on [0..255].

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# Resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
# Resetting  variables to save memory

train = []
test = []
val = []
l = []

# %%
# Convert class vectors to binary class matrices (one-hot encoding)

y_train = to_categorical(y_train, num_classes=4)
y_val = to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# %% [markdown]
# # 4. Model Training

# %%
#from tensorflow.keras.models import load_model

#model = load_model("/content/drive/MyDrive/S6/Mini Project/Multiclass Arch 2.h5")

# %%
# Building the model

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 1)))
model.add(BatchNormalization())
model.add(Conv2D(32, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_8 (Conv2D)           (None, 148, 148, 32)      320
#
#  batch_normalization_8 (Batc  (None, 148, 148, 32)     128
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 146, 146, 32)      9248
#
#  batch_normalization_9 (Batc  (None, 146, 146, 32)     128
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 73, 73, 32)       0
#  2D)
#
#  conv2d_10 (Conv2D)          (None, 71, 71, 64)        18496
#
#  batch_normalization_10 (Bat  (None, 71, 71, 64)       256
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 69, 69, 64)        36928
#
#  batch_normalization_11 (Bat  (None, 69, 69, 64)       256
#  chNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 34, 34, 64)       0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 32, 32, 128)       73856
#
#  batch_normalization_12 (Bat  (None, 32, 32, 128)      512
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 30, 30, 128)       147584
#
#  batch_normalization_13 (Bat  (None, 30, 30, 128)      512
#  chNormalization)
#
#  max_pooling2d_6 (MaxPooling  (None, 15, 15, 128)      0
#  2D)
#
#  conv2d_14 (Conv2D)          (None, 13, 13, 256)       295168
#
#  batch_normalization_14 (Bat  (None, 13, 13, 256)      1024
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 11, 11, 256)       590080
#
#  batch_normalization_15 (Bat  (None, 11, 11, 256)      1024
#  chNormalization)
#
#  max_pooling2d_7 (MaxPooling  (None, 5, 5, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 6400)              0
#
#  dense_4 (Dense)             (None, 512)               3277312
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_5 (Dense)             (None, 256)               131328
#
#  dropout_4 (Dropout)         (None, 256)               0
#
#  dense_6 (Dense)             (None, 128)               32896
#
#  dropout_5 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 4,617,572
# Trainable params: 4,615,652
# Non-trainable params: 1,920
# _________________________________________________________________

# %%
len(model.layers)
# Out:
# 28

# %%
# Model Architecture Visualization

from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)

# %%
# Training the model
history = model.fit(x_train, y_train, batch_size=32, epochs=100, validation_data=(x_val, y_val), callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/100
# 310/310 [==============================] - 26s 85ms/step - loss: 1.0870 - accuracy: 0.6654 - val_loss: 2.3327 - val_accuracy: 0.2947 - lr: 0.0010
# Epoch 2/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.4754 - accuracy: 0.8198 - val_loss: 1.9146 - val_accuracy: 0.4903 - lr: 0.0010
# Epoch 3/100
# 310/310 [==============================] - 22s 72ms/step - loss: 0.3727 - accuracy: 0.8725 - val_loss: 29.9369 - val_accuracy: 0.2947 - lr: 0.0010
# Epoch 4/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.2775 - accuracy: 0.9106 - val_loss: 1.0873 - val_accuracy: 0.7166 - lr: 0.0010
# Epoch 5/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.1972 - accuracy: 0.9375 - val_loss: 1.6614 - val_accuracy: 0.5612 - lr: 0.0010
# Epoch 6/100
# 310/310 [==============================] - ETA: 0s - loss: 0.1760 - accuracy: 0.9472
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 310/310 [==============================] - 23s 73ms/step - loss: 0.1760 - accuracy: 0.9472 - val_loss: 1.4658 - val_accuracy: 0.6224 - lr: 0.0010
# Epoch 7/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0829 - accuracy: 0.9760 - val_loss: 0.4720 - val_accuracy: 0.8744 - lr: 3.0000e-04
# Epoch 8/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0623 - accuracy: 0.9826 - val_loss: 4.2181 - val_accuracy: 0.5781 - lr: 3.0000e-04
# Epoch 9/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0594 - accuracy: 0.9844 - val_loss: 0.1510 - val_accuracy: 0.9469 - lr: 3.0000e-04
# Epoch 10/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0415 - accuracy: 0.9867 - val_loss: 0.0538 - val_accuracy: 0.9887 - lr: 3.0000e-04
# Epoch 11/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0402 - accuracy: 0.9892 - val_loss: 0.0658 - val_accuracy: 0.9742 - lr: 3.0000e-04
# Epoch 12/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0398 - accuracy: 0.9893
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0398 - accuracy: 0.9893 - val_loss: 0.4361 - val_accuracy: 0.9227 - lr: 3.0000e-04
# Epoch 13/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0257 - accuracy: 0.9929 - val_loss: 0.1668 - val_accuracy: 0.9638 - lr: 9.0000e-05
# Epoch 14/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0242 - accuracy: 0.9930 - val_loss: 0.0487 - val_accuracy: 0.9895 - lr: 9.0000e-05
# Epoch 15/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0179 - accuracy: 0.9955 - val_loss: 0.3016 - val_accuracy: 0.9356 - lr: 9.0000e-05
# Epoch 16/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0196 - accuracy: 0.9936
# Epoch 16: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0196 - accuracy: 0.9936 - val_loss: 0.0610 - val_accuracy: 0.9887 - lr: 9.0000e-05
# Epoch 17/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0139 - accuracy: 0.9963 - val_loss: 0.0348 - val_accuracy: 0.9944 - lr: 2.7000e-05
# Epoch 18/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0119 - accuracy: 0.9976 - val_loss: 0.0367 - val_accuracy: 0.9968 - lr: 2.7000e-05
# Epoch 19/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0101 - accuracy: 0.9972 - val_loss: 0.0305 - val_accuracy: 0.9968 - lr: 2.7000e-05
# Epoch 20/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0091 - accuracy: 0.9969
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0091 - accuracy: 0.9969 - val_loss: 0.0372 - val_accuracy: 0.9936 - lr: 2.7000e-05
# Epoch 21/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0092 - accuracy: 0.9980 - val_loss: 0.0309 - val_accuracy: 0.9952 - lr: 8.1000e-06
# Epoch 22/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0076 - accuracy: 0.9984
# Epoch 22: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0076 - accuracy: 0.9984 - val_loss: 0.0312 - val_accuracy: 0.9960 - lr: 8.1000e-06
# Epoch 23/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0068 - accuracy: 0.9975 - val_loss: 0.0304 - val_accuracy: 0.9968 - lr: 2.4300e-06
# Epoch 24/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0075 - accuracy: 0.9979
# Epoch 24: ReduceLROnPlateau reducing learning rate to 1e-06.
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0075 - accuracy: 0.9979 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 2.4300e-06
# Epoch 25/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 26/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0087 - accuracy: 0.9980 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 27/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0056 - accuracy: 0.9986 - val_loss: 0.0312 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 28/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0057 - accuracy: 0.9985 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 29/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0082 - accuracy: 0.9986 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 30/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0055 - accuracy: 0.9986 - val_loss: 0.0312 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 31/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0053 - accuracy: 0.9989 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 32/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0078 - accuracy: 0.9982 - val_loss: 0.0309 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 33/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0310 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 34/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0058 - accuracy: 0.9987 - val_loss: 0.0306 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 35/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0064 - accuracy: 0.9985 - val_loss: 0.0309 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 36/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0060 - accuracy: 0.9986 - val_loss: 0.0302 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 37/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0078 - accuracy: 0.9976 - val_loss: 0.0301 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 38/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0056 - accuracy: 0.9987 - val_loss: 0.0304 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 39/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0057 - accuracy: 0.9986 - val_loss: 0.0309 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 40/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0055 - accuracy: 0.9990 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 41/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0064 - accuracy: 0.9979 - val_loss: 0.0310 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 42/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0074 - accuracy: 0.9978 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 43/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0057 - accuracy: 0.9988 - val_loss: 0.0306 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 44/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.0311 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 45/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0053 - accuracy: 0.9987 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 46/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0058 - accuracy: 0.9990 - val_loss: 0.0311 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 47/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0057 - accuracy: 0.9982 - val_loss: 0.0309 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 48/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0048 - accuracy: 0.9987 - val_loss: 0.0310 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 49/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0075 - accuracy: 0.9978 - val_loss: 0.0311 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 50/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0064 - accuracy: 0.9983 - val_loss: 0.0312 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 51/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.0311 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 52/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0067 - accuracy: 0.9982 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 53/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0044 - accuracy: 0.9991 - val_loss: 0.0306 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 54/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0052 - accuracy: 0.9987 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 55/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0075 - accuracy: 0.9975 - val_loss: 0.0303 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 56/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0067 - accuracy: 0.9985 - val_loss: 0.0303 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 57/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0054 - accuracy: 0.9990 - val_loss: 0.0305 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 58/100
# 310/310 [==============================] - 23s 74ms/step - loss: 0.0048 - accuracy: 0.9986 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 59/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 0.0303 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 60/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0069 - accuracy: 0.9984 - val_loss: 0.0305 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 61/100
# 310/310 [==============================] - 23s 74ms/step - loss: 0.0056 - accuracy: 0.9992 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 62/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0062 - accuracy: 0.9987 - val_loss: 0.0309 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 63/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0313 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 64/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0059 - accuracy: 0.9983 - val_loss: 0.0315 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 65/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0054 - accuracy: 0.9982 - val_loss: 0.0316 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 66/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0316 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 67/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0054 - accuracy: 0.9988 - val_loss: 0.0313 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 68/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.0314 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 69/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0055 - accuracy: 0.9985 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 70/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0050 - accuracy: 0.9987 - val_loss: 0.0305 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 71/100
# 310/310 [==============================] - 23s 74ms/step - loss: 0.0047 - accuracy: 0.9989 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 72/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0306 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 73/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0051 - accuracy: 0.9986 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 74/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0056 - accuracy: 0.9981 - val_loss: 0.0307 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 75/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0045 - accuracy: 0.9990 - val_loss: 0.0308 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 76/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0061 - accuracy: 0.9983 - val_loss: 0.0304 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 77/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0306 - val_accuracy: 0.9960 - lr: 1.0000e-06
# Epoch 78/100
# 310/310 [==============================] - 23s 74ms/step - loss: 0.0041 - accuracy: 0.9991 - val_loss: 0.0302 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 79/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0045 - accuracy: 0.9989 - val_loss: 0.0300 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 80/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0062 - accuracy: 0.9977 - val_loss: 0.0298 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 81/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0044 - accuracy: 0.9989 - val_loss: 0.0302 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 82/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0057 - accuracy: 0.9981 - val_loss: 0.0303 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 83/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0046 - accuracy: 0.9989 - val_loss: 0.0298 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 84/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0073 - accuracy: 0.9983 - val_loss: 0.0306 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 85/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0045 - accuracy: 0.9988 - val_loss: 0.0305 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 86/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0042 - accuracy: 0.9991 - val_loss: 0.0305 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 87/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0051 - accuracy: 0.9988 - val_loss: 0.0301 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 88/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0037 - accuracy: 0.9992 - val_loss: 0.0300 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 89/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0061 - accuracy: 0.9986 - val_loss: 0.0298 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 90/100
# 310/310 [==============================] - 23s 74ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0301 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 91/100
# 310/310 [==============================] - 23s 76ms/step - loss: 0.0058 - accuracy: 0.9986 - val_loss: 0.0302 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 92/100
# 310/310 [==============================] - 23s 76ms/step - loss: 0.0084 - accuracy: 0.9977 - val_loss: 0.0304 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 93/100
# 310/310 [==============================] - 23s 74ms/step - loss: 0.0068 - accuracy: 0.9980 - val_loss: 0.0302 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 94/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0051 - accuracy: 0.9985 - val_loss: 0.0303 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 95/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0046 - accuracy: 0.9987 - val_loss: 0.0300 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 96/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0051 - accuracy: 0.9989 - val_loss: 0.0300 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 97/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 0.0296 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 98/100
# 310/310 [==============================] - 23s 75ms/step - loss: 0.0039 - accuracy: 0.9989 - val_loss: 0.0299 - val_accuracy: 0.9976 - lr: 1.0000e-06
# Epoch 99/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0021 - accuracy: 0.9997 - val_loss: 0.0301 - val_accuracy: 0.9968 - lr: 1.0000e-06
# Epoch 100/100
# 310/310 [==============================] - 23s 73ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0300 - val_accuracy: 0.9976 - lr: 1.0000e-06

# %%
print("Loss of the model is - ", model.evaluate(x_test, y_test)[0])
print("Accuracy of the model is - ", model.evaluate(x_test, y_test)[1] * 100, "%")
# Out:
# 39/39 [==============================] - 1s 20ms/step - loss: 0.0257 - accuracy: 0.9936
# Loss of the model is -  0.025652756914496422
# 39/39 [==============================] - 1s 19ms/step - loss: 0.0257 - accuracy: 0.9936
# Accuracy of the model is -  99.35691356658936 %

# %%
#model.save("Model of Jv2 [99.27% acc] Dataset 5.1.1, Arch 1, 100 epoch, 16 batch size.h5")

# %% [markdown]
# # 5. Post-Training Analysis:

# %%
plt.figure(figsize=[10,6])
plt.plot(history.history["accuracy"], label = "Train acc")
plt.plot(history.history["val_accuracy"], label = "Validation acc")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label = "Train loss")
plt.plot(history.history['val_loss'], label = "Validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # 6. Precision, Recall, F1-score, Support

# %%
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)  # Convert predictions to class labels
true_labels = np.argmax(y_test, axis=1)  # Convert true labels to class labels
# Out:
# 39/39 [==============================] - 1s 19ms/step

# %%
print(classification_report(true_labels, predicted_labels, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    PNEUMONIA       1.00      1.00      1.00       427
#       NORMAL       0.99      0.99      0.99       350
# TUBERCULOSIS       1.00      0.97      0.98       100
#      COVID19       0.99      1.00      0.99       367
#
#     accuracy                           0.99      1244
#    macro avg       0.99      0.99      0.99      1244
# weighted avg       0.99      0.99      0.99      1244

# %% [markdown]
# # 7. Confusion Matrix

# %%
cm = confusion_matrix(true_labels, predicted_labels)
cm
# Out:
# array([[425,   1,   0,   1],
#        [  0, 348,   0,   2],
#        [  0,   3,  97,   0],
#        [  1,   0,   0, 366]])

# %%
cm = pd.DataFrame(cm, index=labels, columns=labels)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(cm, cmap="Blues", linecolor='black', linewidth=1, annot=True, fmt='', xticklabels=labels, yticklabels=labels)
plt.show()

# %% [markdown]
# # 8. ROC Curve

# %%
y_pred = model.predict(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

num_classes = 4

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure(figsize=(12,12))

# Plot ROC curves for each class
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for class %s' % (roc_auc[i], labels[i]))

# Plot micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], label='Micro-average ROC curve (area = %0.2f)' % roc_auc["micro"], linestyle=':', linewidth=4)

# Add labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 39/39 [==============================] - 1s 18ms/step

# %% [markdown]
# # 9. Visualizing the predicted images

# %%
correct = np.nonzero(predicted_labels == true_labels)[0]
incorrect = np.nonzero(predicted_labels != true_labels)[0]

# %%
correct
# Out:
# array([   0,    1,    2, ..., 1241, 1242, 1243])

# %%
correct.size
# Out:
# 1236

# %%
incorrect
# Out:
# array([  79,  299,  470,  581,  810,  861,  868, 1060])

# %%
incorrect.size
# Out:
# 8

# %%
# Visualize correctly classified images

fig, axes = plt.subplots(2, 3, figsize=(10, 8))
fig.suptitle('Correctly Classified Images', fontsize=16)
for i, idx in enumerate(correct[:6]):
    row = i // 3
    col = i % 3
    axes[row, col].imshow(x_test[idx].reshape(img_size, img_size), cmap="gray", interpolation='none')
    axes[row, col].set_title("Predicted Class: {}\nTrue Class: {}".format(labels[predicted_labels[idx]], labels[true_labels[idx]]))
    axes[row, col].axis('off')
plt.tight_layout()
plt.show()

# %%
# Visualize incorrectly classified images

fig, axes = plt.subplots(2, 3, figsize=(10, 8))
fig.suptitle('Incorrectly Classified Images', fontsize=16)
for i, idx in enumerate(incorrect[:6]):
    row = i // 3
    col = i % 3
    axes[row, col].imshow(x_test[idx].reshape(img_size, img_size), cmap="gray", interpolation='none')
    axes[row, col].set_title("Predicted Class: {}\nTrue Class: {}".format(labels[predicted_labels[idx]], labels[true_labels[idx]]))
    axes[row, col].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10. Random Predictions

# %%
image = '/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test/TUBERCULOSIS/1.3.6.1.4.1.25403.163683357445804.11044.20131119114302.50.png'
def preprocess_image(image_path):
    img_arr = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_arr = cv2.resize(img_arr, (img_size, img_size))
    preprocessed_img = np.array(resized_arr) / 255.0
    preprocessed_img = preprocessed_img.reshape(-1, img_size, img_size, 1)
    return preprocessed_img

# Assuming 'image' is the variable containing the path to the image you want to predict
preprocessed_img = preprocess_image(image)
prediction = model.predict(preprocessed_img)
predicted_class = labels[np.argmax(prediction)]
print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 297ms/step
# Predicted class: TUBERCULOSIS
