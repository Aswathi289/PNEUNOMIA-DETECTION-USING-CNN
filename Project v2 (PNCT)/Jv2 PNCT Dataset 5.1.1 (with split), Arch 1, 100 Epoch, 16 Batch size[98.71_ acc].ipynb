# %% [markdown]
# # Importing the necessary libraries

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import keras
from keras.models import Sequential
from keras.layers import Dense, Conv2D , MaxPool2D , Flatten , Dropout , BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.metrics import classification_report,confusion_matrix
from sklearn.model_selection import train_test_split
from keras.utils import to_categorical
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # 1. Loading the dataset

# %%
# Define the labels
labels = ['PNEUMONIA', 'NORMAL', 'TUBERCULOSIS', 'COVID19']

# Set the image size
img_size = 150

# Function to load the training, test, and validation data
def get_training_data(data_dir):
    data = [] 
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        i = 1
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                data.append([resized_arr, class_num])
                if(i%200 == 0):
                  print(i,class_num)
                i+=1
            except Exception as e:
                print(e)
    print("Data loaded")
    print()
    return np.array(data, dtype=object)

# Function to load the half of the data to 2 variables
def get_training_data_split(data_dir):
    data = [] 
    remaining_data = []
    
    for label in labels: 
        path = os.path.join(data_dir, label)
        class_num = labels.index(label)
        i = 1
        
        # Calculate the number of images in the folder
        total_images = len(os.listdir(path))
        half_images = total_images // 2
        
        for img in os.listdir(path):
            try:
                img_arr = cv2.imread(os.path.join(path, img), cv2.IMREAD_GRAYSCALE)
                resized_arr = cv2.resize(img_arr, (img_size, img_size))
                if i <= half_images:
                    data.append([resized_arr, class_num])
                else:
                    remaining_data.append([resized_arr, class_num])
                if i % 200 == 0:
                    print(i, class_num)
                i += 1
            except Exception as e:
                print(e)
    
    print("Data loaded")
    print()
    return np.array(data, dtype=object), np.array(remaining_data, dtype=object)

# %%
# Load the data

train, remaining_data = get_training_data_split('/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/train')
test = get_training_data('/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test')
val = get_training_data('/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/val')
# Out:
# 200 0
# 400 0
# 600 0
# 800 0
# 1000 0
# 1200 0
# 1400 0
# 1600 0
# 1800 0
# 2000 0
# 2200 0
# 2400 0
# 2600 0
# 2800 0
# 3000 0
# 3200 0
# 3400 0
# 200 1
# 400 1
# 600 1
# 800 1
# 1000 1
# 1200 1
# 1400 1
# 1600 1
# 1800 1
# 2000 1
# 2200 1
# 2400 1
# 2600 1
# 2800 1
# 200 2
# 400 2
# 600 2
# 800 2
# 200 3
# 400 3
# 600 3
# 800 3
# 1000 3
# 1200 3
# 1400 3
# 1600 3
# 1800 3
# 2000 3
# 2200 3
# 2400 3
# 2600 3
# 2800 3
# Data loaded
#
# 200 0
# 400 0
# 200 1
# 200 3
# Data loaded
#
# 200 0
# 400 0
# 200 1
# 200 3
# Data loaded

# %%
# Load the data

#train = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/train')
#test = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test')
#val = get_training_data('/content/drive/MyDrive/Prathyush Project/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/val')

# %% [markdown]
# # 2. Data Exploration

# %%
print(train[300])
train.shape
# Out:
# [array([[77, 91, 96, ..., 37, 33, 42],
#         [52, 61, 81, ..., 38, 33, 47],
#         [57, 59, 59, ..., 33, 29, 44],
#         ...,
#         [19, 19, 17, ..., 28, 28, 28],
#         [19, 19, 15, ..., 27, 28, 28],
#         [19, 19, 15, ..., 27, 28, 28]], dtype=uint8) 0]
# (4958, 2)

# %%
print(remaining_data[300])
remaining_data.shape
# Out:
# [array([[44, 49, 53, ..., 63, 64, 71],
#         [49, 54, 54, ..., 69, 66, 79],
#         [52, 52, 56, ..., 71, 79, 78],
#         ...,
#         [22, 17, 14, ..., 47,  6, 18],
#         [18, 17, 14, ..., 45,  7, 12],
#         [17, 17, 14, ..., 46,  9, 13]], dtype=uint8) 0]
# (4960, 2)

# %%
l1 = []
l2 = []

for i in train:
    if(i[1] == 0):
        l1.append("Pneumonia")
    elif(i[1] == 1):
        l1.append("Normal")
    elif(i[1] == 2):
        l1.append("Tuberculosis")
    elif(i[1] == 3):
        l1.append("Covid19")
print(l1)

for i in remaining_data:
    if(i[1] == 0):
        l2.append("Pneumonia")
    elif(i[1] == 1):
        l2.append("Normal")
    elif(i[1] == 2):
        l2.append("Tuberculosis")
    elif(i[1] == 3):
        l2.append("Covid19")
print(l2)
# Out:
# ['Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumon ...
# ['Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumonia', 'Pneumon ...

# %%
sns.set_style('darkgrid')
sns.countplot(x=l1)
# Out:
# <Axes: ylabel='count'>

# %%
sns.set_style('darkgrid')
sns.countplot(x=l2)
# Out:
# <Axes: ylabel='count'>

# %%
# Previewing an image from each class

plt.figure(figsize = (5,5))
plt.imshow(train[0][0], cmap='gray')
plt.title(labels[train[0][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[3600][0], cmap='gray')
plt.title(labels[train[3600][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[6600][0], cmap='gray')
plt.title(labels[train[6500][1]])

plt.figure(figsize = (5,5))
plt.imshow(train[-1][0], cmap='gray')
plt.title(labels[train[-1][1]])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-10-34bfd8161950> in <cell line: 12>()
#      10
#      11 plt.figure(figsize = (5,5))
# ---> 12 plt.imshow(train[6600][0], cmap='gray')
#      13 plt.title(labels[train[6500][1]])
#      14
#
# IndexError: index 6600 is out of bounds for axis 0 with size 4958

# %%
# Split the data into features and labels

x_train = []
y_train = []
x_remaining_data = []
y_remaining_data = []
x_val = []
y_val = []
x_test = []
y_test = []

for feature, label in train:
    x_train.append(feature)
    y_train.append(label)
for feature, label in remaining_data:
    x_remaining_data.append(feature)
    y_remaining_data.append(label)
for feature, label in test:
    x_test.append(feature)
    y_test.append(label)
for feature, label in val:
    x_val.append(feature)
    y_val.append(label)

# %%
# Accessing the no. of elements of each class in train, test, and val respectively

from collections import Counter

def get_element_frequency(arr):
    frequency_counter = Counter(arr)
    return frequency_counter

for i in (y_train,y_remaining_data,y_test,y_val):
    frequency = get_element_frequency(i)
    for element, count in frequency.items():
        print(f"The element {element} appears {count} times.")
    print()
# Out:
# The element 0 appears 1712 times.
# The element 1 appears 1400 times.
# The element 2 appears 406 times.
# The element 3 appears 1440 times.
#
# The element 0 appears 1713 times.
# The element 1 appears 1400 times.
# The element 2 appears 407 times.
# The element 3 appears 1440 times.
#
# The element 0 appears 427 times.
# The element 1 appears 350 times.
# The element 2 appears 100 times.
# The element 3 appears 367 times.
#
# The element 0 appears 427 times.
# The element 1 appears 350 times.
# The element 2 appears 99 times.
# The element 3 appears 366 times.

# %%
num_test_samples = len(x_train)
print("Number of x_train samples:", num_test_samples)

num_test_samples = len(x_remaining_data)
print("Number of x_remaining_data samples:", num_test_samples)

num_test_samples = len(x_test)
print("Number of x_test samples:", num_test_samples)

num_test_samples = len(x_val)
print("Number of x_val samples:", num_test_samples)
# Out:
# Number of x_train samples: 4958
# Number of x_remaining_data samples: 4960
# Number of x_test samples: 1244
# Number of x_val samples: 1242

# %% [markdown]
# # 3. Data Preprocessing

# %% [markdown]
# **Normalization:** We perform a grayscale normalization to reduce the effect of illumination's differences.Moreover the CNN converges faster on [0..1] data than on [0..255].

# %%
# Normalize the data
x_train = np.array(x_train) / 255
x_remaining_data = np.array(x_remaining_data) / 255
x_val = np.array(x_val) / 255
x_test = np.array(x_test) / 255

# %%
# Resize data for deep learning 
x_train = x_train.reshape(-1, img_size, img_size, 1)
y_train = np.array(y_train)

x_remaining_data = x_remaining_data.reshape(-1, img_size, img_size, 1)
y_remaining_data = np.array(y_remaining_data)

x_val = x_val.reshape(-1, img_size, img_size, 1)
y_val = np.array(y_val)

x_test = x_test.reshape(-1, img_size, img_size, 1)
y_test = np.array(y_test)

# %%
# Convert class vectors to binary class matrices (one-hot encoding)

y_train = to_categorical(y_train, num_classes=4)
y_remaining_data = to_categorical(y_remaining_data, num_classes=4)
y_val = to_categorical(y_val, num_classes=4)
y_test = to_categorical(y_test, num_classes=4)

# %%
print(x_train.shape)
print(y_train.shape)
print(x_remaining_data.shape)
print(y_remaining_data.shape)
print(x_test.shape)
print(y_test.shape)
print(x_val.shape)
print(y_val.shape)
# Out:
# (4958, 150, 150, 1)
# (4958, 4)
# (4960, 150, 150, 1)
# (4960, 4)
# (1244, 150, 150, 1)
# (1244, 4)
# (1242, 150, 150, 1)
# (1242, 4)

# %% [markdown]
# # 4. Model Training

# %%
# from tensorflow.keras.models import load_model

# model = load_model("/content/Model of Jv2 [95.52% acc] Dataset 5.1, 100 epoch, 16 batch size.h5")

# %%
# Building the model

model = Sequential()

model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(150, 150, 1)))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(256, (3, 3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPool2D((2, 2)))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(4, activation='softmax'))  # Adjust the number of classes here
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 148, 148, 32)      320
#
#  batch_normalization (BatchN  (None, 148, 148, 32)     128
#  ormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 74, 74, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 72, 72, 64)        18496
#
#  batch_normalization_1 (Batc  (None, 72, 72, 64)       256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 36, 36, 64)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 34, 34, 128)       73856
#
#  batch_normalization_2 (Batc  (None, 34, 34, 128)      512
#  hNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 17, 17, 128)      0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 15, 15, 256)       295168
#
#  batch_normalization_3 (Batc  (None, 15, 15, 256)      1024
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  flatten (Flatten)           (None, 12544)             0
#
#  dense (Dense)               (None, 512)               6423040
#
#  dropout (Dropout)           (None, 512)               0
#
#  dense_1 (Dense)             (None, 256)               131328
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_3 (Dense)             (None, 4)                 516
#
# =================================================================
# Total params: 6,977,540
# Trainable params: 6,976,580
# Non-trainable params: 960
# _________________________________________________________________

# %%
len(model.layers)
# Out:
# 20

# %%
# Model Architecture Visualization

from keras.utils.vis_utils import plot_model

plot_model(model, to_file='model_architecture.png', show_shapes=True, show_layer_names=True)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5)
learning_rate_reduction = ReduceLROnPlateau(monitor='val_accuracy', patience=2, verbose=1, factor=0.3, min_lr=0.000001)

# %%
# Training the model

#history = model.fit(x_train, y_train, batch_size=16, epochs=100, validation_data=(x_val, y_val), callbacks=[learning_rate_reduction])
history = model.fit(x_train, y_train, batch_size=16, epochs=100, validation_data=(x_val, y_val), callbacks=[learning_rate_reduction])
#callbacks = [early_stopping]
# Out:
# Epoch 1/100
# 310/310 [==============================] - 21s 24ms/step - loss: 2.4275 - accuracy: 0.5964 - val_loss: 1.8092 - val_accuracy: 0.2947 - lr: 0.0010
# Epoch 2/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.6603 - accuracy: 0.7596 - val_loss: 1.2119 - val_accuracy: 0.6312 - lr: 0.0010
# Epoch 3/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.4249 - accuracy: 0.8399 - val_loss: 0.7791 - val_accuracy: 0.6828 - lr: 0.0010
# Epoch 4/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.3643 - accuracy: 0.8812 - val_loss: 3.4182 - val_accuracy: 0.4533 - lr: 0.0010
# Epoch 5/100
# 310/310 [==============================] - ETA: 0s - loss: 0.3112 - accuracy: 0.8969
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0003000000142492354.
# 310/310 [==============================] - 6s 19ms/step - loss: 0.3112 - accuracy: 0.8969 - val_loss: 4.6381 - val_accuracy: 0.6514 - lr: 0.0010
# Epoch 6/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.1879 - accuracy: 0.9355 - val_loss: 0.2697 - val_accuracy: 0.8535 - lr: 3.0000e-04
# Epoch 7/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.1694 - accuracy: 0.9488 - val_loss: 0.7921 - val_accuracy: 0.6594 - lr: 3.0000e-04
# Epoch 8/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.1246 - accuracy: 0.9591 - val_loss: 0.3680 - val_accuracy: 0.8583 - lr: 3.0000e-04
# Epoch 9/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.1182 - accuracy: 0.9633 - val_loss: 1.5974 - val_accuracy: 0.7593 - lr: 3.0000e-04
# Epoch 10/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.1030 - accuracy: 0.9665 - val_loss: 0.3161 - val_accuracy: 0.8599 - lr: 3.0000e-04
# Epoch 11/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0963 - accuracy: 0.9679 - val_loss: 0.6762 - val_accuracy: 0.6844 - lr: 3.0000e-04
# Epoch 12/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0926 - accuracy: 0.9728
# Epoch 12: ReduceLROnPlateau reducing learning rate to 9.000000427477062e-05.
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0926 - accuracy: 0.9728 - val_loss: 0.4707 - val_accuracy: 0.7947 - lr: 3.0000e-04
# Epoch 13/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0886 - accuracy: 0.9728 - val_loss: 0.3283 - val_accuracy: 0.8462 - lr: 9.0000e-05
# Epoch 14/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0674 - accuracy: 0.9804
# Epoch 14: ReduceLROnPlateau reducing learning rate to 2.700000040931627e-05.
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0674 - accuracy: 0.9804 - val_loss: 0.4784 - val_accuracy: 0.8261 - lr: 9.0000e-05
# Epoch 15/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0484 - accuracy: 0.9861 - val_loss: 0.1861 - val_accuracy: 0.9501 - lr: 2.7000e-05
# Epoch 16/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0463 - accuracy: 0.9863 - val_loss: 0.0737 - val_accuracy: 0.9702 - lr: 2.7000e-05
# Epoch 17/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0443 - accuracy: 0.9853 - val_loss: 0.0712 - val_accuracy: 0.9734 - lr: 2.7000e-05
# Epoch 18/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0382 - accuracy: 0.9881 - val_loss: 0.0779 - val_accuracy: 0.9807 - lr: 2.7000e-05
# Epoch 19/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0371 - accuracy: 0.9887 - val_loss: 0.2882 - val_accuracy: 0.8937 - lr: 2.7000e-05
# Epoch 20/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0354 - accuracy: 0.9901
# Epoch 20: ReduceLROnPlateau reducing learning rate to 8.100000013655517e-06.
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0354 - accuracy: 0.9901 - val_loss: 0.1348 - val_accuracy: 0.9452 - lr: 2.7000e-05
# Epoch 21/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0310 - accuracy: 0.9903 - val_loss: 0.0888 - val_accuracy: 0.9678 - lr: 8.1000e-06
# Epoch 22/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0309 - accuracy: 0.9909 - val_loss: 0.0589 - val_accuracy: 0.9815 - lr: 8.1000e-06
# Epoch 23/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0313 - accuracy: 0.9913 - val_loss: 0.0575 - val_accuracy: 0.9799 - lr: 8.1000e-06
# Epoch 24/100
# 310/310 [==============================] - ETA: 0s - loss: 0.0394 - accuracy: 0.9879
# Epoch 24: ReduceLROnPlateau reducing learning rate to 2.429999949526973e-06.
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0394 - accuracy: 0.9879 - val_loss: 0.0563 - val_accuracy: 0.9799 - lr: 8.1000e-06
# Epoch 25/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0232 - accuracy: 0.9925 - val_loss: 0.0512 - val_accuracy: 0.9847 - lr: 2.4300e-06
# Epoch 26/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0244 - accuracy: 0.9915 - val_loss: 0.0496 - val_accuracy: 0.9855 - lr: 2.4300e-06
# Epoch 27/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0273 - accuracy: 0.9917 - val_loss: 0.0553 - val_accuracy: 0.9831 - lr: 2.4300e-06
# Epoch 28/100
# 309/310 [============================>.] - ETA: 0s - loss: 0.0217 - accuracy: 0.9937
# Epoch 28: ReduceLROnPlateau reducing learning rate to 1e-06.
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0217 - accuracy: 0.9937 - val_loss: 0.0795 - val_accuracy: 0.9815 - lr: 2.4300e-06
# Epoch 29/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0239 - accuracy: 0.9921 - val_loss: 0.0555 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 30/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0263 - accuracy: 0.9935 - val_loss: 0.0511 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 31/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0221 - accuracy: 0.9942 - val_loss: 0.0541 - val_accuracy: 0.9831 - lr: 1.0000e-06
# Epoch 32/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0256 - accuracy: 0.9925 - val_loss: 0.0533 - val_accuracy: 0.9831 - lr: 1.0000e-06
# Epoch 33/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0273 - accuracy: 0.9937 - val_loss: 0.0550 - val_accuracy: 0.9831 - lr: 1.0000e-06
# Epoch 34/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0271 - accuracy: 0.9915 - val_loss: 0.0531 - val_accuracy: 0.9831 - lr: 1.0000e-06
# Epoch 35/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0270 - accuracy: 0.9925 - val_loss: 0.0494 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 36/100
# 310/310 [==============================] - 7s 21ms/step - loss: 0.0237 - accuracy: 0.9939 - val_loss: 0.0538 - val_accuracy: 0.9831 - lr: 1.0000e-06
# Epoch 37/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0245 - accuracy: 0.9925 - val_loss: 0.0574 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 38/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0240 - accuracy: 0.9937 - val_loss: 0.0557 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 39/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0340 - accuracy: 0.9917 - val_loss: 0.0512 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 40/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0247 - accuracy: 0.9929 - val_loss: 0.0500 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 41/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0267 - accuracy: 0.9921 - val_loss: 0.0534 - val_accuracy: 0.9831 - lr: 1.0000e-06
# Epoch 42/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0250 - accuracy: 0.9913 - val_loss: 0.0500 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 43/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0302 - accuracy: 0.9913 - val_loss: 0.0573 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 44/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0210 - accuracy: 0.9939 - val_loss: 0.0529 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 45/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0276 - accuracy: 0.9935 - val_loss: 0.0503 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 46/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0262 - accuracy: 0.9917 - val_loss: 0.0511 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 47/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0216 - accuracy: 0.9935 - val_loss: 0.0539 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 48/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0246 - accuracy: 0.9921 - val_loss: 0.0511 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 49/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0184 - accuracy: 0.9950 - val_loss: 0.0519 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 50/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0273 - accuracy: 0.9925 - val_loss: 0.0490 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 51/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0246 - accuracy: 0.9923 - val_loss: 0.0529 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 52/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0218 - accuracy: 0.9937 - val_loss: 0.0552 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 53/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0206 - accuracy: 0.9950 - val_loss: 0.0516 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 54/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0218 - accuracy: 0.9931 - val_loss: 0.0513 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 55/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0244 - accuracy: 0.9935 - val_loss: 0.0541 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 56/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.0504 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 57/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0305 - accuracy: 0.9901 - val_loss: 0.0607 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 58/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0243 - accuracy: 0.9933 - val_loss: 0.0502 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 59/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0260 - accuracy: 0.9923 - val_loss: 0.0548 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 60/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0207 - accuracy: 0.9946 - val_loss: 0.0526 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 61/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 0.0560 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 62/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0194 - accuracy: 0.9931 - val_loss: 0.0500 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 63/100
# 310/310 [==============================] - 7s 21ms/step - loss: 0.0197 - accuracy: 0.9935 - val_loss: 0.0507 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 64/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0250 - accuracy: 0.9927 - val_loss: 0.0660 - val_accuracy: 0.9831 - lr: 1.0000e-06
# Epoch 65/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0259 - accuracy: 0.9935 - val_loss: 0.0529 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 66/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0282 - accuracy: 0.9915 - val_loss: 0.0533 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 67/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0199 - accuracy: 0.9939 - val_loss: 0.0523 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 68/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0239 - accuracy: 0.9929 - val_loss: 0.0468 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 69/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.0547 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 70/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0229 - accuracy: 0.9929 - val_loss: 0.0575 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 71/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0238 - accuracy: 0.9927 - val_loss: 0.0498 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 72/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0188 - accuracy: 0.9944 - val_loss: 0.0502 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 73/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0200 - accuracy: 0.9933 - val_loss: 0.0491 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 74/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0245 - accuracy: 0.9939 - val_loss: 0.0568 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 75/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0239 - accuracy: 0.9935 - val_loss: 0.0480 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 76/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0219 - accuracy: 0.9923 - val_loss: 0.0499 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 77/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0224 - accuracy: 0.9948 - val_loss: 0.0489 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 78/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0291 - accuracy: 0.9929 - val_loss: 0.0476 - val_accuracy: 0.9871 - lr: 1.0000e-06
# Epoch 79/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0228 - accuracy: 0.9948 - val_loss: 0.0470 - val_accuracy: 0.9871 - lr: 1.0000e-06
# Epoch 80/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0231 - accuracy: 0.9944 - val_loss: 0.0573 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 81/100
# 310/310 [==============================] - 7s 21ms/step - loss: 0.0213 - accuracy: 0.9942 - val_loss: 0.0501 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 82/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0211 - accuracy: 0.9927 - val_loss: 0.0505 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 83/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0186 - accuracy: 0.9946 - val_loss: 0.0584 - val_accuracy: 0.9847 - lr: 1.0000e-06
# Epoch 84/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0162 - accuracy: 0.9950 - val_loss: 0.0553 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 85/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0212 - accuracy: 0.9931 - val_loss: 0.0502 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 86/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0175 - accuracy: 0.9946 - val_loss: 0.0492 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 87/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0175 - accuracy: 0.9950 - val_loss: 0.0492 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 88/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0188 - accuracy: 0.9956 - val_loss: 0.0560 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 89/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0268 - accuracy: 0.9927 - val_loss: 0.0501 - val_accuracy: 0.9871 - lr: 1.0000e-06
# Epoch 90/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0225 - accuracy: 0.9933 - val_loss: 0.0536 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 91/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.0552 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 92/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0244 - accuracy: 0.9933 - val_loss: 0.0459 - val_accuracy: 0.9879 - lr: 1.0000e-06
# Epoch 93/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0183 - accuracy: 0.9944 - val_loss: 0.0487 - val_accuracy: 0.9879 - lr: 1.0000e-06
# Epoch 94/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0278 - accuracy: 0.9929 - val_loss: 0.0485 - val_accuracy: 0.9879 - lr: 1.0000e-06
# Epoch 95/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0232 - accuracy: 0.9942 - val_loss: 0.0549 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 96/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0204 - accuracy: 0.9944 - val_loss: 0.0659 - val_accuracy: 0.9839 - lr: 1.0000e-06
# Epoch 97/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0191 - accuracy: 0.9952 - val_loss: 0.0484 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 98/100
# 310/310 [==============================] - 6s 19ms/step - loss: 0.0201 - accuracy: 0.9939 - val_loss: 0.0531 - val_accuracy: 0.9863 - lr: 1.0000e-06
# Epoch 99/100
# 310/310 [==============================] - 6s 21ms/step - loss: 0.0172 - accuracy: 0.9944 - val_loss: 0.0507 - val_accuracy: 0.9855 - lr: 1.0000e-06
# Epoch 100/100
# 310/310 [==============================] - 6s 20ms/step - loss: 0.0139 - accuracy: 0.9964 - val_loss: 0.0459 - val_accuracy: 0.9879 - lr: 1.0000e-06

# %%
print("Loss of the model is - ", model.evaluate(x_test, y_test)[0])
print("Accuracy of the model is - ", model.evaluate(x_test, y_test)[1] * 100, "%")
# Out:
# 39/39 [==============================] - 1s 16ms/step - loss: 0.0538 - accuracy: 0.9871
# Loss of the model is -  0.053752727806568146
# 39/39 [==============================] - 0s 10ms/step - loss: 0.0538 - accuracy: 0.9871
# Accuracy of the model is -  98.71382713317871 %

# %%
print("Loss of the model is - ", model.evaluate(x_remaining_data, y_remaining_data)[0])
print("Accuracy of the model is - ", model.evaluate(x_remaining_data, y_remaining_data)[1] * 100, "%")
# Out:
# 155/155 [==============================] - 2s 11ms/step - loss: 0.0563 - accuracy: 0.9841
# Loss of the model is -  0.0563121996819973
# 155/155 [==============================] - 2s 12ms/step - loss: 0.0563 - accuracy: 0.9841
# Accuracy of the model is -  98.40725660324097 %

# %%
#model.save("Model of Jv2 [99.51% acc] Dataset 5.1.1, Arch 1, 100 epoch, 16 batch size.h5")

# %% [markdown]
# # 5. Post-Training Analysis:

# %%
plt.figure(figsize=[10,6])
plt.plot(history.history["accuracy"], label = "Train acc")
plt.plot(history.history["val_accuracy"], label = "Validation acc")
plt.legend()
plt.show()

# %%
plt.figure(figsize=(10,6))
plt.plot(history.history['loss'], label = "Train loss")
plt.plot(history.history['val_loss'], label = "Validation loss")
plt.legend()
plt.show()

# %% [markdown]
# # 6. Precision, Recall, F1-score, Support

# %%
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)  # Convert predictions to class labels
true_labels = np.argmax(y_test, axis=1)  # Convert true labels to class labels
# Out:
# 39/39 [==============================] - 0s 9ms/step

# %%
print(classification_report(true_labels, predicted_labels, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#    PNEUMONIA       0.99      1.00      0.99       427
#       NORMAL       0.98      0.98      0.98       350
# TUBERCULOSIS       0.97      0.99      0.98       100
#      COVID19       0.99      0.98      0.99       367
#
#     accuracy                           0.99      1244
#    macro avg       0.98      0.99      0.99      1244
# weighted avg       0.99      0.99      0.99      1244

# %% [markdown]
# # 7. Confusion Matrix

# %%
cm = confusion_matrix(true_labels, predicted_labels)
cm
# Out:
# array([[425,   0,   0,   2],
#        [  2, 343,   3,   2],
#        [  0,   1,  99,   0],
#        [  1,   5,   0, 361]])

# %%
cm = pd.DataFrame(cm, index=labels, columns=labels)

# %%
plt.figure(figsize=(8,8))
sns.heatmap(cm, cmap="Blues", linecolor='black', linewidth=1, annot=True, fmt='', xticklabels=labels, yticklabels=labels)
plt.show()

# %% [markdown]
# # 8. ROC Curve

# %%
y_pred = model.predict(x_test)

fpr = dict()
tpr = dict()
roc_auc = dict()

num_classes = 4

for i in range(num_classes):
    fpr[i], tpr[i], _ = roc_curve(y_test[:, i], y_pred[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])

fpr["micro"], tpr["micro"], _ = roc_curve(y_test.ravel(), y_pred.ravel())
roc_auc["micro"] = auc(fpr["micro"], tpr["micro"])

plt.figure(figsize=(12,12))

# Plot ROC curves for each class
for i in range(num_classes):
    plt.plot(fpr[i], tpr[i], label='ROC curve (area = %0.2f) for class %s' % (roc_auc[i], labels[i]))

# Plot micro-average ROC curve
plt.plot(fpr["micro"], tpr["micro"], label='Micro-average ROC curve (area = %0.2f)' % roc_auc["micro"], linestyle=':', linewidth=4)

# Add labels and legend
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC)')
plt.legend(loc="lower right")
plt.show()
# Out:
# 39/39 [==============================] - 0s 11ms/step

# %% [markdown]
# # 9. Visualizing the predicted images

# %%
correct = np.nonzero(predicted_labels == true_labels)[0]
incorrect = np.nonzero(predicted_labels != true_labels)[0]

# %%
correct
# Out:
# array([   0,    1,    2, ..., 1241, 1242, 1243])

# %%
correct.size
# Out:
# 1238

# %%
incorrect
# Out:
# array([ 79, 299, 470, 514, 868, 914])

# %%
incorrect.size
# Out:
# 6

# %%
# Visualize correctly classified images

fig, axes = plt.subplots(2, 3, figsize=(10, 8))
fig.suptitle('Correctly Classified Images', fontsize=16)
for i, idx in enumerate(correct[:6]):
    row = i // 3
    col = i % 3
    axes[row, col].imshow(x_test[idx].reshape(img_size, img_size), cmap="gray", interpolation='none')
    axes[row, col].set_title("Predicted Class: {}\nTrue Class: {}".format(labels[predicted_labels[idx]], labels[true_labels[idx]]))
    axes[row, col].axis('off')
plt.tight_layout()
plt.show()

# %%
# Visualize incorrectly classified images

fig, axes = plt.subplots(2, 3, figsize=(10, 8))
fig.suptitle('Incorrectly Classified Images', fontsize=16)
for i, idx in enumerate(incorrect[:6]):
    row = i // 3
    col = i % 3
    axes[row, col].imshow(x_test[idx].reshape(img_size, img_size), cmap="gray", interpolation='none')
    axes[row, col].set_title("Predicted Class: {}\nTrue Class: {}".format(labels[predicted_labels[idx]], labels[true_labels[idx]]))
    axes[row, col].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 10. Random Predictions

# %%
image = '/content/drive/MyDrive/S6/Mini Project/Project v2 (PNCT)/v2 Dataset 5.1.1 (replaced with COVID-19 Radiography Dataset)/test/PNEUMONIA/VIRUS-4320648-0006.jpeg'
def preprocess_image(image_path):
    img_arr = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    resized_arr = cv2.resize(img_arr, (img_size, img_size))
    preprocessed_img = np.array(resized_arr) / 255.0
    preprocessed_img = preprocessed_img.reshape(-1, img_size, img_size, 1)
    return preprocessed_img

# Assuming 'image' is the variable containing the path to the image you want to predict
preprocessed_img = preprocess_image(image)
prediction = model.predict(preprocessed_img)
predicted_class = labels[np.argmax(prediction)]
print("Predicted class:", predicted_class)
# Out:
# 1/1 [==============================] - 0s 333ms/step
# Predicted class: PNEUMONIA
